# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_squared_error
from imblearn.over_sampling import SMOTE

import lightgbm as lgb  # for large datasets

# %%
# LOAD & SHUFFLE DATA
df = pd.read_csv("/content/merged_students.csv")
df = df.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)
print("Dataset shape:", df.shape)
print(df.head())
# Out:
# Dataset shape: (500, 21)
#   Gender_x    State     District  Taluka         City  \
# 0     male  Gujarat       Rajkot  Gondal       Moviya
# 1     male  Gujarat       Rajkot  Gondal       Moviya
# 2     male  Gujarat       Rajkot  Gondal       Moviya
# 3   female  Gujarat  Sabarkantha    Idar       Laloda
# 4   female  Gujarat  Sabarkantha    Idar  Gambhirpura
#
#              School_name[0] City_type School_medium  School_std  \
# 0  6580224900270b10031c1ee7     Rural      Gujarati           5
# 1  658021132fec1162ab3345ab     Rural      Gujarati           5
# 2  6580224900270b10031c1ee7     Rural      Gujarati           8
# 3  657b579a60bba63ffcd0f9c6     Rural       English           0
# 4  657b579a60bba63ffcd0f9c6     Rural       English          -1
#
#      ParentOccupation  ...  Family_income  Cast Disabled  \
# 0           Zookeeper  ...       1-2 Lakh    SC        0
# 1           Zookeeper  ...       1-2 Lakh    SC        0
# 2  Fitness Instructor  ...       4-6 Lakh    SC        0
# 3               Nurse  ...       4-6 Lakh  SEBC        0
# 4              Artist  ...       1-2 Lakh  Open       50
#
#                         Reason StudentID  Gender_y Attendance_Rate  \
# 0   Bullying and Social Issues       362      Male       87.731765
# 1  Family and Economic Factors        74      Male       60.634039
# 2   Bullying and Social Issues       375      Male       84.149103
# 3    Transportation and Access       156    Female       70.725229
# 4    Transportation and Access       105      Male       67.693569
#
#    Unnamed: 18  Test_Score      Fees
# 0          NaN          69  0.678959
# 1          NaN          50  0.833915
# 2          NaN          63  0.164070
# 3          NaN          50  0.317850
# 4          NaN          56  0.916810
#
# [5 rows x 21 columns]

# %%
import google.generativeai as genai

# Configure Gemini
genai.configure(api_key="AIzaSyBJKAcnT3TkCSGIEO5q-khX3oYxmfjSp3I")

# Function to call Gemini for explanations
def generate_explanation_with_gemini(reason_text: str) -> str:
    model = genai.GenerativeModel("gemini-1.5-flash")
    prompt = f"""
    You are an assistant that explains student dropout risk.
    Based only on the reasons: {reason_text}, generate a short, clear human-readable explanation.
    """
    response = model.generate_content(prompt)
    return response.text.strip()

# %%
# RULE-BASED RISK SCORING
def calculate_risk_for_model(row):
    score = 0
    reasons = []

    # Attendance
    if row["Attendance_Rate"] < 50:
        score += 35
        reasons.append("Low attendance")
    elif row["Attendance_Rate"] < 75:
        score += 25
        reasons.append("Moderate attendance")
    else:
        score += 0
        reasons.append("Good attendance")

    # Single Test Score
    if row["Test_Score"] < 40:
        score += 30
        reasons.append("Low test score")
    elif 40 <= row["Test_Score"] <= 70:
        score += 15
        reasons.append("Average test score")
    else:  # > 70
        score += 0
        reasons.append("Good test score")

    # Fees (values between 0.1 and 1)
    if row["Fees"] < 0.4:
        score += 0
        reasons.append("Low risk fees")
    elif 0.4 <= row["Fees"] <= 0.7:
        score += 15
        reasons.append("Moderate risk fees")
    else:  # > 0.7
        score += 30
        reasons.append("High risk fees")

    # Normalize score
    score = min(score, 100)

    # Risk Level (based on score)
    if score >= 60:
        level, color = "High", "Red"
    elif score >= 30:
        level, color = "Medium", "Orange"
    else:
        level, color = "Low", "Green"

    # Combine reasons
    if "Reason" in row and pd.notna(row["Reason"]) and row["Reason"].strip() != "":
        reason_text = row["Reason"] + ", " + ", ".join(reasons)
    else:
        reason_text = ", ".join(reasons) if reasons else "None"

    return pd.Series([score, level, color, reason_text])


# Apply to dataset
df[['Risk_Score', 'Risk_Level', 'Risk_Color', 'Dropout_Reason']] = df.apply(
    calculate_risk_for_model, axis=1
)

# DYNAMIC CLASS CREATION (Quantile-based)
q1, q2 = df["Risk_Score"].quantile([0.33, 0.66])

def risk_class(score):
    if score <= q1:
        return 0  # Low
    elif score <= q2:
        return 1  # Medium
    else:
        return 2  # High

df["At_Risk"] = df["Risk_Score"].apply(risk_class)

# Map back to labels/colors
risk_map = {0: ("Low", "Green"), 1: ("Medium", "Orange"), 2: ("High", "Red")}
df["Risk_Level"], df["Risk_Color"] = zip(*df["At_Risk"].map(risk_map))

# Features & Target
features = ["Attendance_Rate", "Test_Score", "Fees"]
X = df[features]
y_class = df["At_Risk"]
y_score = df["Risk_Score"]

# %%
# STEP 5: SCALE FEATURES
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# HANDLE CLASS IMBALANCE (SMOTE, memory efficient)
# Large dataset check
if len(df) < 50000:  # Small/medium dataset -> SMOTE safe
    sm = SMOTE(random_state=RANDOM_STATE)
    X_res, y_res = sm.fit_resample(X_scaled, y_class)
else:
    # Large dataset -> Skip SMOTE
    X_res, y_res = X_scaled, y_class

# %%
# TRAIN-TEST SPLIT
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=RANDOM_STATE, stratify=y_res
)

# %%
# RANDOM FOREST CLASSIFICATION (or LightGBM for large data)
if len(df) <= 50000:
    cls_model = RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        random_state=RANDOM_STATE,
        class_weight="balanced",
        n_jobs=-1
    )
else:
    cls_model = lgb.LGBMClassifier(
        n_estimators=200,
        max_depth=15,
        learning_rate=0.1,
        random_state=RANDOM_STATE
    )

cls_model.fit(X_train, y_train)
y_pred_cls = cls_model.predict(X_test)
y_prob_cls = cls_model.predict_proba(X_test)[:, 1]

print("\nClassification Report:\n", classification_report(y_test, y_pred_cls))
print("Accuracy:", accuracy_score(y_test, y_pred_cls))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_cls))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00        42
#            2       1.00      1.00      1.00        42
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126
#
# Accuracy: 1.0
# Confusion Matrix:
#  [[42  0  0]
#  [ 0 42  0]
#  [ 0  0 42]]

# %%
# PREDICTIONS & MAPPING (FULL DATASET)
y_prob_full = cls_model.predict_proba(X_scaled)  # predictions for all rows

def map_risk_level(prob_row):
    idx = np.argmax(prob_row)   # find index of max probability
    return ["Low", "Medium", "High"][idx]

# Assign predictions to full dataframe
df["Dropout_Probability"] = y_prob_full.max(axis=1)  # highest probability
df["Predicted_Risk_Level"] = [map_risk_level(p) for p in y_prob_full]

# %%
# STEP 10: SAVE RESULTS
output_cols = ["StudentID", "Risk_Score", "Risk_Level", "Risk_Color", "Dropout_Reason",
               "Dropout_Probability", "Predicted_Risk_Level"]
df_results = df[output_cols]
df_results.to_csv("student_risk_predictions.csv", index=False)
print("Results saved to student_risk_predictions.csv")
# Out:
# Results saved to student_risk_predictions.csv

# %%
# 1. Risk Level Distribution (Bar Chart)
plt.figure(figsize=(6,4))
sns.countplot(x=df["Risk_Level"], palette="Set2", order=df["Risk_Level"].value_counts().index)
plt.title("Distribution of Students by Risk Level")
plt.ylabel("Number of Students")
plt.xlabel("Risk Level")
plt.show()

from textwrap import shorten

# Count top reasons
reason_counts = df_results["Dropout_Reason"].value_counts().head(10)

# Trim long text to max 40 characters
reason_labels = [shorten(r, width=40, placeholder="...") for r in reason_counts.index]

plt.figure(figsize=(8,6))
sns.barplot(
    y=reason_labels,
    x=reason_counts.values,
    palette="coolwarm"
)
plt.title("Top Dropout Reasons", fontsize=14, fontweight="bold")
plt.xlabel("Count")
plt.ylabel("Reason")
plt.tight_layout()
plt.show()


plt.figure(figsize=(7,5))
sns.barplot(x="Risk_Level", y="Attendance_Rate", data=df, palette="Set1", ci=None)
plt.title("Average Attendance by Risk Level")
plt.xlabel("Risk Level")
plt.ylabel("Average Attendance (%)")
plt.show()
# Out:
# /tmp/ipython-input-3938160122.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Risk_Level"], palette="Set2", order=df["Risk_Level"].value_counts().index)
# /tmp/ipython-input-3938160122.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-3938160122.py:31: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Risk_Level", y="Attendance_Rate", data=df, palette="Set1", ci=None)
# /tmp/ipython-input-3938160122.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Risk_Level", y="Attendance_Rate", data=df, palette="Set1", ci=None)

# %%
features = ["Attendance_Rate", "Test_Score", "Risk_Score"]  # numeric features

# Group means
risk_means = df.groupby("Risk_Level")[features].mean()

# Plot as grouped bar chart
risk_means.plot(kind="bar", figsize=(8,6))
plt.title("Average Feature Values per Risk Level", fontsize=14, fontweight="bold")
plt.ylabel("Average Value")
plt.xlabel("Risk Level")
plt.xticks(rotation=0)
plt.legend(title="Features")
plt.show()



# ============================
# 6. Risk Level Pie Chart
# ============================
plt.figure(figsize=(6,6))
df["Risk_Level"].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap="Set3")
plt.title("Risk Level Proportion")
plt.ylabel("")
plt.show()




# ============================
# 7. Attendance Histogram
# ============================
plt.figure(figsize=(7,5))
sns.histplot(df["Attendance_Rate"], bins=20, kde=True, color="skyblue")
plt.title("Distribution of Attendance Rates")
plt.xlabel("Attendance %")
plt.ylabel("Number of Students")
plt.show()

# %%
# STEP 14: TREND ANALYSIS DASHBOARD STYLE VISUALIZATION (FIXED)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))  # 2 rows, 2 columns = 4 graphs
plt.subplots_adjust(hspace=0.6, wspace=0.4, left=0.08, right=0.95, top=0.9, bottom=0.08)

# 1. Pie chart - Risk Levels
df["Risk_Level"].value_counts().plot.pie(
    autopct="%1.1f%%", startangle=90, colors=["green","orange","red"], ax=axes[0,0]
)
axes[0,0].set_ylabel("")
axes[0,0].set_title("Distribution of Students by Risk Level")

# 2. Attendance Distribution (Histogram)
sns.histplot(data=df, x="Attendance_Rate", hue="Risk_Level",
             multiple="stack", bins=15, palette="Set2", ax=axes[0,1])
axes[0,1].set_title("Attendance Distribution by Risk Level")

# 3. Dropout Reasons (Top 10, trimmed text)
top_reasons = df["Dropout_Reason"].value_counts().head(10)
top_reasons.index = [r[:40] + "..." if len(r) > 40 else r for r in top_reasons.index]
sns.barplot(x=top_reasons.values, y=top_reasons.index, palette="viridis", ax=axes[1,0])
axes[1,0].set_title("Top 10 Dropout Reasons (Trimmed)")
axes[1,0].set_xlabel("Count")

# 4. Attendance vs Risk Level (Bar Chart)
avg_attendance = df.groupby("Risk_Level")["Attendance_Rate"].mean().reset_index()
sns.barplot(x="Risk_Level", y="Attendance_Rate", data=avg_attendance, palette="Set2", ax=axes[1,1])
axes[1,1].set_title("Average Attendance by Risk Level")
axes[1,1].set_ylabel("Average Attendance Rate")

plt.show()
# Out:
# /tmp/ipython-input-743177016.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_reasons.values, y=top_reasons.index, palette="viridis", ax=axes[1,0])
# /tmp/ipython-input-743177016.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Risk_Level", y="Attendance_Rate", data=avg_attendance, palette="Set2", ax=axes[1,1])

# %%
# Single-case Rule-based risk for testing (updated)
def calculate_risk_single(case):
    row = pd.Series(case)
    score = 0
    reasons = []

    # Attendance
    if row["Attendance_Rate"] < 50:
        score += 35
        reasons.append("Low attendance")
    elif row["Attendance_Rate"] < 75:
        score += 25
        reasons.append("Moderate attendance")
    else:
        score += 0
        reasons.append("Good attendance")

    # Test Score (use same logic as original rule-based)
    if row["Test_Score"] < 40:
        score += 30
        reasons.append("Low test score")
    elif 40 <= row["Test_Score"] <= 70:
        score += 15
        reasons.append("Average test score")
    else:
        score += 0
        reasons.append("Good test score")

    # Fees
    if row["Fees"] < 0.4:
        score += 0
        reasons.append("Low risk fees")
    elif 0.4 <= row["Fees"] <= 0.7:
        score += 15
        reasons.append("Moderate risk fees")
    else:
        score += 30
        reasons.append("High risk fees")

    # Normalize
    score = min(score, 100)

    # Risk Level
    if score >= 60:
        level = "High"
        color = "Red"
    elif score >= 30:
        level = "Medium"
        color = "Orange"
    else:
        level = "Low"
        color = "Green"

    return score, level, color, reasons


# ✅ Hybrid model (Rule-based + ML) updated
def hybrid_model(case, ml_model, scaler, features):
    # Rule-based score
    rb_score, rb_level, rb_color, _ = calculate_risk_single(case)

    # ML score (probability of 'High Risk' class)
    X_test_df = pd.DataFrame([case], columns=features)
    X_test_scaled = scaler.transform(X_test_df)
    ml_prob_array = ml_model.predict_proba(X_test_scaled)[0]
    ml_score = ml_prob_array[2] * 100  # High Risk probability

    # Average combination
    hybrid_score = (rb_score + ml_score) / 2

    # Map to level
    if hybrid_score >= 60:
        hybrid_level = "High"
        hybrid_color = "Red"
    elif hybrid_score >= 30:
        hybrid_level = "Medium"
        hybrid_color = "Orange"
    else:
        hybrid_level = "Low"
        hybrid_color = "Green"

    return hybrid_score, hybrid_level, hybrid_color

def test_all_models(test_cases, ml_model=None, hybrid_model=None, features=None, scaler=None):
    for i, case in enumerate(test_cases):
        print(f"\n--- Test Case {i+1} ---")

        # Rule-based
        rb_score, rb_level, rb_color, rb_reasons = calculate_risk_single(case)
        reason_text = ", ".join(rb_reasons)
        print("Rule-based Risk:")
        print(f"Score: {rb_score}, Level: {rb_level}, Color: {rb_color}, Reasons: {reason_text}")

        # ✅ Gemini explanation
        human_expl = generate_explanation_with_gemini(reason_text)
        print("Explanation:")
        print(human_expl)

        # ML model
        if ml_model is not None and features is not None and scaler is not None:
            X_test_df = pd.DataFrame([case], columns=features)
            X_test_scaled = scaler.transform(X_test_df)

            ml_pred_class = ml_model.predict(X_test_scaled)[0]
            ml_prob_array = ml_model.predict_proba(X_test_scaled)[0]

            ml_pred_label = ["Low", "Medium", "High"][ml_pred_class]
            ml_prob_max = ml_prob_array.max()

            print("ML Model Risk:")
            print(f"Prediction: {ml_pred_label}, Probability: {ml_prob_max:.2f}")

        # Hybrid model
        if hybrid_model is not None and ml_model is not None:
            hybrid_score, hybrid_level, hybrid_color = hybrid_model(case, ml_model, scaler, features)
            print("Hybrid Model Risk:")
            print(f"Score: {hybrid_score:.2f}, Level: {hybrid_level}, Color: {hybrid_color}")


# 🔹 Example test cases updated to match new schema
test_cases = [
    {"Attendance_Rate": 30, "Test_Score": 25, "Fees": 0.8},
    {"Attendance_Rate": 85, "Test_Score": 80, "Fees": 0.3},
    {"Attendance_Rate": 65, "Test_Score": 60, "Fees": 0.5},
    {"Attendance_Rate": 45, "Test_Score": 75, "Fees": 0.9},
    {"Attendance_Rate": 80, "Test_Score": 35, "Fees": 0.4},
    {"Attendance_Rate": 55, "Test_Score": 30, "Fees": 0.6}
]

# %%
test_all_models(
    test_cases,
    ml_model=cls_model,
    hybrid_model=hybrid_model,
    features=features,
    scaler=scaler
)
# Out:
# --- Test Case 1 ---
# Rule-based Risk:
# Score: 95, Level: High, Color: Red, Reasons: Low attendance, Low test score, High risk fees
# Explanation:
# Students are at risk of dropping out if they miss a lot of classes (low attendance), perform poorly on tests (low test scores), and face high tuition costs (high-risk fees).  These factors combined can make it difficult for them to succeed and stay enrolled.
# ML Model Risk:
# Prediction: High, Probability: 1.00
# Hybrid Model Risk:
# Score: 97.50, Level: High, Color: Red
#
# --- Test Case 2 ---
# Rule-based Risk:
# Score: 0, Level: Low, Color: Green, Reasons: Good attendance, Good test score, Low risk fees
# Explanation:
# Students with good attendance, good test scores, and low risk fees show a very low risk of dropping out.  These factors indicate engagement and a manageable financial situation, both key to academic success.
# ML Model Risk:
# Prediction: Low, Probability: 1.00
# Hybrid Model Risk:
# Score: 0.00, Level: Low, Color: Green
#
# --- Test Case 3 ---
# Rule-based Risk:
# Score: 55, Level: Medium, Color: Orange, Reasons: Moderate attendance, Average test score, Moderate risk fees
# Explanation:
# This student shows a moderate risk of dropping out.  While their test scores are average, inconsistent attendance and moderate financial pressure from fees combine to create a concerning pattern.  These factors suggest the student may be struggling to stay engaged or afford their education.
# ML Model Risk:
# Prediction: High, Probability: 0.99
# Hybrid Model Risk:
# Score: 77.00, Level: High, Color: Red
#
# --- Test Case 4 ---
# Rule-based Risk:
# Score: 65, Level: High, Color: Red, Reasons: Low attendance, Good test score, High risk fees
# Explanation:
# This student has good test scores, suggesting academic ability. However, poor attendance and high fees create a significant risk of them dropping out.  The high cost of tuition may be a barrier, especially combined with infrequent class participation.
# ML Model Risk:
# Prediction: High, Probability: 0.74
# Hybrid Model Risk:
# Score: 69.75, Level: High, Color: Red
#
# --- Test Case 5 ---
# Rule-based Risk:
# Score: 45, Level: Medium, Color: Orange, Reasons: Good attendance, Low test score, Moderate risk fees
# Explanation:
# This student has good attendance, which is positive. However, low test scores are a concern, suggesting academic struggles.  Moderate risk fees could also be a contributing factor to potential dropout, as financial strain can impact a student's ability to focus on their studies.  While good attendance is a strength, the combination of low test scores and moderate financial risk increases the overall likelihood of this student dropping out.
# ML Model Risk:
# Prediction: Low, Probability: 0.96
# Hybrid Model Risk:
# Score: 23.00, Level: Low, Color: Green
#
# --- Test Case 6 ---
# Rule-based Risk:
# Score: 70, Level: High, Color: Red, Reasons: Moderate attendance, Low test score, Moderate risk fees
# Explanation:
# This student is at risk of dropping out due to a combination of factors.  Their moderate attendance suggests they may not be fully engaged in their studies. Low test scores indicate academic struggles, and moderate risk fees could create financial pressure, further impacting their ability to continue their education.  These factors together increase the likelihood of the student leaving school.
# ML Model Risk:
# Prediction: High, Probability: 0.99
# Hybrid Model Risk:
# Score: 84.50, Level: High, Color: Red
